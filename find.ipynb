# %%
import pandas as pd

# %%
df = pd.read_csv('data/idf.csv')

# %%
df.head(50)
# Out:
#               Name               Code  \
# 0   Benoitgofadmin  Benoitgofadmin433
# 1            gofro          gofro8082
# 2      marcantoine    marcantoine7264
# 3          fdfdfdf        fdfdfdf8089
# 4            gigea          gigea9232
# 5            gadfi          gadfi4727
# 6          martine        martine5308
# 7      martinenela    martinenela3806
# 8             kikl           kikl8935
# 9              aaa             aaa904
# 10          chichi          chichi873
# 11              xi             xi8338
# 12              ws             ws6193
#
#                                              Question    Reponse  \
# 0   Dans quelle ville as-tu couru ta première cour...   martique
# 1             Quel est le nom de ton club de course ?   castanet
# 2           Quel est le prénom de ton premier coach ?      cesar
# 3           Quel est le prénom de ton premier coach ?      gofro
# 4           Quel est le prénom de ton premier coach ?      gofro
# ...

# %%
mdf = pd.read_csv('data/mdf.csv')

# %%
mdf.head()
# Out:
#   athlete     message                reponse                     date
# 0      xi  youpiyoupi     oui trop fun merci  <class 'datetime.date'>
# 1      xi      encore  c vraimet fuinny baby  <class 'datetime.date'>
